# %%
from task_creator_utils import create_task
import sys
import os

# sys.path.append(os.path.abspath('../NN_TopOpt'))

vertices = [[0, 0], [0, 0.6], [0.25, 0.6], [0.25, 0]]
task_name = "cantilever_beam"
constraints = {"fixed_x": [], "fixed_y": [], "fixed_xy": [[0, [0, 0.6]]]}
loads = [[[0.25, [0.25, 0.35]], [0, -0.000005]]]

create_task(vertices, task_name, constraints, loads)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000399007s, CPU 0.000712s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.213345s, CPU 0.21434s)
# Info    : 7142 nodes 14286 elements
# Info    : Writing 'cantilever_beam.msh'...
# Info    : Done writing 'cantilever_beam.msh'
# Info    : Reading 'cantilever_beam.msh'...
# Info    : 9 entities
# Info    : 7142 nodes
# Info    : 13942 elements
# Info    : Done reading 'cantilever_beam.msh'
# Compute areas ...
# ...
# 100%|██████████| 13942/13942 [00:00<00:00, 219130.65it/s]
# Whole area 0.15
