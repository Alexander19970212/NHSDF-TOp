# %%
from task_creator_utils import create_task
import sys
import os

# sys.path.append(os.path.abspath('../NN_TopOpt'))

# %%
vertices = [[0, 0], [0, 0.6], [0.25, 0.6], [0.25, 0]]
task_name = "cantilever_beam_high_resolution"
constraints = {"fixed_x": [], "fixed_y": [], "fixed_xy": [[0, [0, 0.6]]]}
loads = [[[0.25, [0.275, 0.325]], [0, -80]]] # 0.000005

create_task(vertices, task_name, constraints, loads, meshsize = 0.005)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.00496267s, CPU 0.00101s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.209081s, CPU 0.186679s)
# Info    : 7142 nodes 14286 elements
# Info    : Writing 'cantilever_beam_high_resolution.msh'...
# Info    : Done writing 'cantilever_beam_high_resolution.msh'
# Info    : Reading 'cantilever_beam_high_resolution.msh'...
# Info    : 9 entities
# Info    : 7142 nodes
# Info    : 13942 elements
# Info    : Done reading 'cantilever_beam_high_resolution.msh'
# Compute areas ...
# ...
# 100%|██████████| 13942/13942 [00:00<00:00, 212704.69it/s]
# Whole area 0.15

# %%
# basic beam
vertices = [[0, 0], [0, 0.5], [0.5, 0.5], [0.5, 0]]
task_name = "basic_beam"
constraints = {"fixed_x": [], "fixed_y": [], "fixed_xy": [[[0, 0.5], 0]]}
loads = [[[0.5, 0.0], [0, -80]]]

create_task(vertices, task_name, constraints, loads, meshsize = 0.01)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000269755s, CPU 0.000237s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0815647s, CPU 0.081803s)
# Info    : 3016 nodes 6034 elements
# Info    : Writing 'basic_beam.msh'...
# Info    : Done writing 'basic_beam.msh'
# Info    : Reading 'basic_beam.msh'...
# Info    : 9 entities
# Info    : 3016 nodes
# Info    : 5830 elements
# Info    : Done reading 'basic_beam.msh'
# Compute areas ...
# ...
# 100%|██████████| 5830/5830 [00:00<00:00, 218858.06it/s]
# Whole area 0.25

# %%
3* 0.5/4
# Out:
# 0.375

# %%
# Michell type structure
vertices = [[0, 0], [0, 0.25], [0.5, 0.25], [0.5, 0]]
task_name = "Mechell_type_structure"
constraints = {"fixed_x": [], "fixed_y": [[0.5, 0]], "fixed_xy": [[0, 0]]}
loads = [[[[0.245, 0.255], 0], [0, -300]], [[[0.12, 0.13], 0], [0, -150]], [[[0.37, 0.38], 0], [0, -150]]]

create_task(vertices, task_name, constraints, loads, meshsize = 0.005)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.00061959s, CPU 0.001182s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.318475s, CPU 0.314208s)
# Info    : 5964 nodes 11930 elements
# Info    : Writing 'Mechell_type_structure.msh'...
# Info    : Done writing 'Mechell_type_structure.msh'
# Info    : Reading 'Mechell_type_structure.msh'...
# Info    : 9 entities
# Info    : 5964 nodes
# Info    : 11626 elements
# Info    : Done reading 'Mechell_type_structure.msh'
# Compute areas ...
# ...
# 100%|██████████| 11626/11626 [00:00<00:00, 108381.92it/s]
# Whole area 0.125

# %%
#MBB beam
vertices = [[0, 0], [0, 0.4], [2.4, 0.4], [2.4, 0]]
task_name = "MBB_beam"
constraints = {"fixed_x": [], "fixed_y": [[2.4, 0]], "fixed_xy": [[0, 0]]}
loads = [[[[1.15, 1.25], 0.4], [0, -80]]]

create_task(vertices, task_name, constraints, loads, meshsize = 0.012)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000646767s, CPU 0.00114s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.402683s, CPU 0.403428s)
# Info    : 8034 nodes 16070 elements
# Info    : Writing 'MBB_beam.msh'...
# Info    : Done writing 'MBB_beam.msh'
# Info    : Reading 'MBB_beam.msh'...
# Info    : 9 entities
# Info    : 8034 nodes
# Info    : 15598 elements
# Info    : Done reading 'MBB_beam.msh'
# Compute areas ...
# ...
# 100%|██████████| 15598/15598 [00:00<00:00, 107387.20it/s]
# Whole area 0.9600000000000001

# %%
#MBB beam half
vertices = [[0, 0], [0, 0.4], [1.2, 0.4], [1.2, 0]]
task_name = "MBB_beam_half_hrez"
constraints = {"fixed_x": [[0, [0, 0.4]]], "fixed_y": [[1.2, 0]], "fixed_xy": []}
loads = [[[0, 0.4], [0, -80]]]

create_task(vertices, task_name, constraints, loads, meshsize = 0.002)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.00145114s, CPU 0.001645s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 6.67249s, CPU 6.52512s)
# Info    : 139530 nodes 279062 elements
# Info    : Writing 'MBB_beam_half_hrez.msh'...
# Info    : Done writing 'MBB_beam_half_hrez.msh'
# Info    : Reading 'MBB_beam_half_hrez.msh'...
# Info    : 9 entities
# Info    : 139530 nodes
# Info    : 277458 elements
# Info    : Done reading 'MBB_beam_half_hrez.msh'
# Compute areas ...
# ...
# 100%|██████████| 277458/277458 [00:01<00:00, 141734.52it/s]
# Whole area 0.48000000000000004

# %%
#MBB beam half
vertices = [[0, 0], [0, 1.5], [0.5, 1.5], [0.5, 0.5], [1.5, 0.5], [1.5, 0]]
task_name = "Brecket"
constraints = {"fixed_x": [], "fixed_y": [], "fixed_xy": [[[0, 0.5], 1.5]]}
loads = [[[[1.0, 1.5], 0.5], [0, -80]]]

create_task(vertices, task_name, constraints, loads, meshsize = 0.017)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 40%] Meshing curve 3 (Line)
# Info    : [ 60%] Meshing curve 4 (Line)
# Info    : [ 70%] Meshing curve 5 (Line)
# Info    : [ 90%] Meshing curve 6 (Line)
# Info    : Done meshing 1D (Wall 0.000298518s, CPU 0.000246s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.12402s, CPU 0.122298s)
# Info    : 5317 nodes 10638 elements
# Info    : Writing 'Brecket.msh'...
# Info    : Done writing 'Brecket.msh'
# Info    : Reading 'Brecket.msh'...
# Info    : 13 entities
# Info    : 5317 nodes
# Info    : 10276 elements
# Info    : Done reading 'Brecket.msh'
# Compute areas ...
# ...
# 100%|██████████| 10276/10276 [00:00<00:00, 176584.91it/s]
# Whole area 1.25

# %%
#MBB beam half
vertices = [[0, 0], [0, 0.5], [1, 0.5], [1, 0]]
task_name = "Cantilever_beam_distributed_load"
constraints = {"fixed_x": [], "fixed_y": [], "fixed_xy": [[0, [0, 0.5]]]}
loads = [[[[0, 1], 0.5], [0, 80]]]

create_task(vertices, task_name, constraints, loads, meshsize = 0.01)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000411347s, CPU 0.000682s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.146567s, CPU 0.146309s)
# Info    : 5964 nodes 11930 elements
# Info    : Writing 'Cantilever_beam_distributed_load.msh'...
# Info    : Done writing 'Cantilever_beam_distributed_load.msh'
# Info    : Reading 'Cantilever_beam_distributed_load.msh'...
# Info    : 9 entities
# Info    : 5964 nodes
# Info    : 11626 elements
# Info    : Done reading 'Cantilever_beam_distributed_load.msh'
# Compute areas ...
# ...
# 100%|██████████| 11626/11626 [00:00<00:00, 229466.36it/s]
# Whole area 0.5
