# %%
import sys
import os

# Add the parent directory of NN_TopOpt to the system path
sys.path.append(os.path.abspath('NN_TopOpt'))

from vizualization_utils import experiment_table, last_modified, plot_objective_history
from vizualization_utils import opt_animation, last_iteration
# %matplotlib ipympl

# %%
experiment_files = ['9522243329.json', # c + L_volfr
                    ]

# %%
print(last_modified())
plot_objective_history([last_modified()])
# Out:
# 9522243329.json
# Parameters that differ between experiments:
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/vizualization_utils.py:272: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/vizualization_utils.py:278: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend()
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/vizualization_utils.py:284: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax3.legend()
# ...

# %%
last_iteration(last_modified(), save_fig=True)
# Out:
# Info    : Reading 'test_problems/sigmund11k.msh'...
# Info    : 9 entities
# Info    : 5693 nodes
# Info    : 11064 elements
# Info    : Done reading 'test_problems/sigmund11k.msh'
# Compute areas ...
# ...
# 100%|██████████| 11064/11064 [00:00<00:00, 224934.46it/s]
# Whole area 0.12
