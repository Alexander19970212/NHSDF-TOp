# %%
import sys
import os

# Add the parent directory of NN_TopOpt to the system path
sys.path.append(os.path.abspath('NN_TopOpt'))

from vizualization_utils import experiment_table, last_modified, plot_objective_history
from vizualization_utils import opt_animation, last_iteration
# %matplotlib ipympl

# %%
# experiment_files = ['2815272192.json',
#                     '9196471915.json', # c + L_volfr
#                     '4048282818.json', # c + L_volfr + L_overlap
#                     '0007554968.json', # c + L_volfr + L_overlap + L_ff
#                     # '9965676109.json', # c + L_volfr + L_overlap + L_ff + L_orgz(str 50)
#                     # '6171792038.json', # c + L_volfr + L_overlap + L_ff + L_orgz(str 70)
#                     '1173445135.json' # c + L_volfr + L_overlap + L_ff + L_orgz(str 90)
#                     ]

experiment_files = ['6976077555.json', '2004172389.json']

# %%
print(last_modified())
# plot_objective_history(['8692095572.json', last_modified()])
plot_objective_history(['4094915919.json', '2105715807.json', last_modified()])
# Out:
# 3757633762.json
# Parameters that differ between experiments:
#
# max_iter:
#   4094915919.json: 200
#   2105715807.json: 200
#   3757633762.json: 150

# %%
opt_animation(last_modified())
# Out:
# Info    : Reading 'test_problems/sigmund11k.msh'...
# Info    : 9 entities
# Info    : 5693 nodes
# Info    : 11064 elements
# Info    : Done reading 'test_problems/sigmund11k.msh'
# Compute areas ...
# ...
# 100%|██████████| 11064/11064 [00:00<00:00, 226071.90it/s]
# Whole area 0.12

# %%
last_iteration('2815272192.json', save_fig=True)
# Out:
# Info    : Reading 'test_problems/sigmund11k.msh'...
# Info    : 9 entities
# Info    : 5693 nodes
# Info    : 11064 elements
# Info    : Done reading 'test_problems/sigmund11k.msh'
# Compute areas ...
# ...
# 100%|██████████| 11064/11064 [00:00<00:00, 233354.35it/s]
# Whole area 0.12

# %%
print(last_modified())
# plot_objective_history([last_modified(), '4005499794.json', '1173445135.json'])
# plot_objective_history([last_modified(), '4720431382.json'])
# Out:
# 2004172389.json

# %%
# 0451352164.json

plot_objective_history(experiment_files)
# Out:
# Parameters that differ between experiments:
#
# smooth_k:
#   6976077555.json: 13
#   2004172389.json: 5

# %%
for file in experiment_files:
    last_iteration(file, save_fig=True)
# Out:
# Info    : Reading 'test_problems/sigmund11k.msh'...
# Info    : 9 entities
# Info    : 5693 nodes
# Info    : 11064 elements
# Info    : Done reading 'test_problems/sigmund11k.msh'
# Compute areas ...
# ...
# 100%|██████████| 11064/11064 [00:00<00:00, 173067.42it/s]
# Whole area 0.12
# Info    : Reading 'test_problems/sigmund11k.msh'...
# Info    : 9 entities
# Info    : 5693 nodes
# Info    : 11064 elements
# Info    : Done reading 'test_problems/sigmund11k.msh'
# Compute areas ...
# ...
# 100%|██████████| 11064/11064 [00:00<00:00, 180752.21it/s]
# Whole area 0.12
# volfrac_loss_pre: 0.024316102266311646
# gaussian_overlap: 0.19760765135288239
# compliance: 7.1685008151689544e-06
# ff_loss: 17550.326171875
# rs_loss: 0.0
# Info    : Reading 'test_problems/sigmund11k.msh'...
# Info    : 9 entities
# Info    : 5693 nodes
# Info    : 11064 elements
# Info    : Done reading 'test_problems/sigmund11k.msh'
# Compute areas ...
# ...
# 100%|██████████| 11064/11064 [00:00<00:00, 178928.34it/s]
# ...
