# %%
import sys
import os

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../models'))
sys.path.append(os.path.abspath('../dataset_generation'))
# sys.path.append('..')
# sys.path.append('../models')
from NN_TopOpt import FeatureMappingDecSDF, FeatureMappingTopOpt, SIMP_basic
from TopOpt import TopOptimizer2D
import yaml

methods = {
    "fm_nn_heaviside": FeatureMappingTopOpt,
}

# %%
import torch 
torch.cuda.empty_cache()

# select the experiment directory
# experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/AE_DeepSDF"
experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF"
# experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/MMD_VAE_DeepSDF"

# config_name = "Cant_beam_half_fm_ae_hv"   # Task 1
config_name = "Brecket_fm_ae_hv"          # Task 2
# config_name = "MBB_beam_half_fm_ae_hv"    # Task 3
# config_name = "Cant_beam_distrL_fm_ae_hv" # Task 4

config_path = f"{experiment_dir}/{config_name}.yaml"

with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

params = config['params']
params['refactoring_markers'] = list(range(38, 80, 5))
print(params['refactoring_markers'])
TopOptimizer = TopOptimizer2D(methods, params)
TopOptimizer.optimize(plot_interval=20)
# Out:
# [38, 43, 48, 53, 58, 63, 68, 73, 78]
# Info    : Reading '../test_problems/Brecket.msh'...
# Info    : 13 entities
# Info    : 5317 nodes
# Info    : 10276 elements
# Info    : Done reading '../test_problems/Brecket.msh'
# Compute areas ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10276/10276 [00:00<00:00, 82584.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10276/10276 [00:00<00:00, 144671.47it/s]
# Whole area 1.25
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10276/10276 [00:00<00:00, 19523.46it/s]
# Fixed case:  fixed_xy [[0, 0.5], 1.5] 31 31
# Loaded loads:  (30,)
# Iteration: 1 | current volfrac: 0.863926 | compliance: 815372.375000
# Iteration: 2 | current volfrac: 0.862763 | compliance: 760478.937500
# Iteration: 3 | current volfrac: 0.861164 | compliance: 734535.000000
# Iteration: 4 | current volfrac: 0.858723 | compliance: 724421.750000
# Iteration: 5 | current volfrac: 0.855628 | compliance: 721508.875000
# Iteration: 6 | current volfrac: 0.851750 | compliance: 720532.500000
# Iteration: 7 | current volfrac: 0.847381 | compliance: 720324.437500
# Iteration: 8 | current volfrac: 0.842307 | compliance: 720820.875000
# Iteration: 9 | current volfrac: 0.836783 | compliance: 721635.187500
# Iteration: 10 | current volfrac: 0.830326 | compliance: 723514.812500
# Iteration: 11 | current volfrac: 0.823655 | compliance: 726819.687500
# Iteration: 12 | current volfrac: 0.815977 | compliance: 731651.875000
# Iteration: 13 | current volfrac: 0.808210 | compliance: 736407.375000
# Iteration: 14 | current volfrac: 0.799455 | compliance: 741772.625000
# Iteration: 15 | current volfrac: 0.789928 | compliance: 746793.250000
# Iteration: 16 | current volfrac: 0.779677 | compliance: 752139.000000
# Iteration: 17 | current volfrac: 0.768750 | compliance: 760850.062500
# Iteration: 18 | current volfrac: 0.756176 | compliance: 771049.875000
# Iteration: 19 | current volfrac: 0.741749 | compliance: 785239.625000
# Iteration: 20 | current volfrac: 0.726442 | compliance: 800465.125000
is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 54 | current volfrac: 0.376913 | compliance: 1356245.750000
# Global iteration 54 is within one of the shape optimization ranges.
# Iteration: 55 | current volfrac: 0.368532 | compliance: 1356416.000000
# Global iteration 55 is within one of the shape optimization ranges.
# Iteration: 56 | current volfrac: 0.358996 | compliance: 1364796.875000
# Global iteration 56 is within one of the shape optimization ranges.
# Iteration: 57 | current volfrac: 0.348960 | compliance: 1391834.250000
# Global iteration 57 is within one of the shape optimization ranges.
# Iteration: 58 | current volfrac: 0.342443 | compliance: 1421081.375000
# Global iteration 58 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 59 | current volfrac: 0.340603 | compliance: 1443860.000000
# Global iteration 59 is within one of the shape optimization ranges.
# Iteration: 60 | current volfrac: 0.346251 | compliance: 1389371.500000
# Global iteration 60 is within one of the shape optimization ranges.
# Iteration: 61 | current volfrac: 0.350404 | compliance: 1361459.500000
# Global iteration 61 is within one of the shape optimization ranges.
# Iteration: 62 | current volfrac: 0.353077 | compliance: 1343564.125000
# Global iteration 62 is within one of the shape optimization ranges.
# Iteration: 63 | current volfrac: 0.353856 | compliance: 1333038.125000
# Global iteration 63 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 64 | current volfrac: 0.347652 | compliance: 1379546.625000
# Global iteration 64 is within one of the shape optimization ranges.
# Iteration: 65 | current volfrac: 0.345197 | compliance: 1373525.750000
# Global iteration 65 is within one of the shape optimization ranges.
# Iteration: 66 | current volfrac: 0.344219 | compliance: 1371542.375000
# Global iteration 66 is within one of the shape optimization ranges.
# Iteration: 67 | current volfrac: 0.346251 | compliance: 1357070.250000
# Global iteration 67 is within one of the shape optimization ranges.
# Iteration: 68 | current volfrac: 0.349816 | compliance: 1333882.875000
# Global iteration 68 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 69 | current volfrac: 0.345565 | compliance: 1391773.750000
# Global iteration 69 is within one of the shape optimization ranges.
# Iteration: 70 | current volfrac: 0.350334 | compliance: 1345721.500000
# Global iteration 70 is within one of the shape optimization ranges.
# Iteration: 71 | current volfrac: 0.351751 | compliance: 1333951.250000
# Global iteration 71 is within one of the shape optimization ranges.
# Iteration: 72 | current volfrac: 0.348917 | compliance: 1344273.250000
# Global iteration 72 is within one of the shape optimization ranges.
# Iteration: 73 | current volfrac: 0.343470 | compliance: 1370501.750000
# Global iteration 73 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 74 | current volfrac: 0.344530 | compliance: 1410267.250000
# Global iteration 74 is within one of the shape optimization ranges.
# Iteration: 75 | current volfrac: 0.341996 | compliance: 1392316.500000
# Global iteration 75 is within one of the shape optimization ranges.
# Iteration: 76 | current volfrac: 0.340934 | compliance: 1385915.750000
# Global iteration 76 is within one of the shape optimization ranges.
# Iteration: 77 | current volfrac: 0.341533 | compliance: 1384459.625000
# Global iteration 77 is within one of the shape optimization ranges.
# Iteration: 78 | current volfrac: 0.343440 | compliance: 1375195.125000
# Global iteration 78 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 79 | current volfrac: 0.360516 | compliance: 1337114.500000
# Global iteration 79 is within one of the shape optimization ranges.

# %%
geometry_features = TopOptimizer.method.gaussian_core.get_geometry()

filename = None
TopOptimizer.plot_final_result(geometry_features, filename=filename)
