# %%
import sys
import os
import json

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../models'))
sys.path.append(os.path.abspath('../dataset_generation'))
# sys.path.append('..')
# sys.path.append('../models')
from NN_TopOpt import FeatureMappingDecSDF, FeatureMappingTopOpt, SIMP_basic
from TopOpt import TopOptimizer2D
import yaml

methods = {
    "fm_nn_heaviside": FeatureMappingTopOpt,
}

# %%
import torch 
torch.cuda.empty_cache()

dataset_type = "quadrangle"
root_dir = "../src/model_comparison/NHSDF"

# select the experiment directory
if dataset_type == "tripple":
    # experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/AE_DeepSDF"
    experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF"
    # experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/MMD_VAE_DeepSDF"
elif dataset_type == "quadrangle":
    experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF_quad"
    root_dir += "_quad"


# config_name = "MBB_beam_half_fm_ae_hv" #
# config_name = "Cant_beam_half_fm_ae_hv"
# config_name = "Cant_beam_distrL_fm_ae_hv"
# config_name = "Brecket_fm_ae_hv"


config_name = "MBB_beam_half" #
# config_name = "Cant_beam"
# config_name = "Cant_beam_distrL"
# config_name = "Brecket"

# config_name = "Square_beam"
# config_name = "Square_beam_distrL"
# config_name = "Square_cantilever_beam"

config_path = f"{experiment_dir}/{config_name}.yaml"

with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

params = config['params']
# params['refactoring_markers'] = list(range(38, 80, 5))
params['refactoring_markers'] = []
# params['treshold'] = 0.5
TopOptimizer = TopOptimizer2D(methods, params)
TopOptimizer.optimize(plot_interval=5)
vf, compliance, max_stress = TopOptimizer.print_metrics()
# Out:
# Info    : Reading '../test_problems/MBB_beam_half.msh'...
# Info    : 9 entities
# Info    : 5710 nodes
# Info    : 11098 elements
# Info    : Done reading '../test_problems/MBB_beam_half.msh'
# Compute areas ...
# 100%|██████████| 11098/11098 [00:00<00:00, 126073.25it/s]
# 100%|██████████| 11098/11098 [00:00<00:00, 167884.10it/s]
# Whole area 0.48
# 100%|██████████| 11098/11098 [00:00<00:00, 32542.90it/s]
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/NN_TopOpt/NN_TopOpt.py:1126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(saved_model_path)
# Fixed case:  fixed_x [0, [0, 0.4]] 41 5710
# Fixed case:  fixed_y [1.2, 0] 1 121
# Loaded loads:  (1,)
# 40
# ../model_weights/frst_VAE_DeepSDF_quad_Bprec_full.pt
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/NN_TopOpt/NN_TopOpt.py:1673: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   self.H.T @ self.volumes/volume_goal - 1
# Iteration: 1 | current volfrac: 0.914835 | compliance: 0.000807
# Iteration: 2 | current volfrac: 0.912116 | compliance: 0.000810
# Iteration: 3 | current volfrac: 0.907957 | compliance: 0.000811
# Iteration: 4 | current volfrac: 0.904219 | compliance: 0.000811
# Iteration: 5 | current volfrac: 0.899953 | compliance: 0.000813
# Iteration: 6 | current volfrac: 0.895589 | compliance: 0.000818
# Iteration: 7 | current volfrac: 0.890801 | compliance: 0.000822
# Iteration: 8 | current volfrac: 0.885404 | compliance: 0.000825
# Iteration: 9 | current volfrac: 0.879686 | compliance: 0.000828
# Iteration: 10 | current volfrac: 0.873584 | compliance: 0.000829
# Iteration: 11 | current volfrac: 0.866854 | compliance: 0.000831
# Iteration: 12 | current volfrac: 0.859447 | compliance: 0.000834
# Iteration: 13 | current volfrac: 0.851640 | compliance: 0.000837
# Iteration: 14 | current volfrac: 0.843930 | compliance: 0.000842
# Iteration: 15 | current volfrac: 0.834590 | compliance: 0.000849
# Iteration: 16 | current volfrac: 0.824703 | compliance: 0.000855
# Iteration: 17 | current volfrac: 0.813734 | compliance: 0.000864
# Iteration: 18 | current volfrac: 0.801838 | compliance: 0.000875
# Iteration: 19 | current volfrac: 0.788541 | compliance: 0.000887
# Iteration: 20 | current volfrac: 0.773619 | compliance: 0.000902
# Iteration: 21 | current volfrac: 0.757006 | compliance: 0.000922
# Iteration: 22 | current volfrac: 0.738651 | compliance: 0.000949
# Iteration: 23 | current volfrac: 0.719400 | compliance: 0.000978
# Iteration: 24 | current volfrac: 0.699647 | compliance: 0.001013
# Iteration: 25 | current volfrac: 0.678073 | compliance: 0.001064
# Iteration: 26 | current volfrac: 0.654006 | compliance: 0.001134
# Iteration: 27 | current volfrac: 0.630278 | compliance: 0.001200
# Iteration: 28 | current volfrac: 0.607255 | compliance: 0.001278
# Iteration: 29 | current volfrac: 0.584524 | compliance: 0.001360
# Iteration: 30 | current volfrac: 0.563494 | compliance: 0.001447
# Iteration: 31 | current volfrac: 0.546186 | compliance: 0.001545
# Iteration: 32 | current volfrac: 0.535391 | compliance: 0.001624
# Iteration: 33 | current volfrac: 0.530865 | compliance: 0.001626
# Iteration: 34 | current volfrac: 0.533724 | compliance: 0.001590
# Iteration: 35 | current volfrac: 0.542582 | compliance: 0.001518
# Iteration: 36 | current volfrac: 0.551425 | compliance: 0.001471
# Iteration: 37 | current volfrac: 0.559922 | compliance: 0.001423
# Iteration: 38 | current volfrac: 0.568905 | compliance: 0.001371
# Iteration: 39 | current volfrac: 0.576079 | compliance: 0.001334
# Iteration: 40 | current volfrac: 0.580417 | compliance: 0.001309
# Global iteration 40 is within one of the shape optimization ranges.
# Iteration: 41 | current volfrac: 0.573932 | compliance: 0.001315
# Global iteration 41 is within one of the shape optimization ranges.
# Iteration: 42 | current volfrac: 0.570811 | compliance: 0.001299
# Global iteration 42 is within one of the shape optimization ranges.
# Iteration: 43 | current volfrac: 0.559674 | compliance: 0.001319
# Global iteration 43 is within one of the shape optimization ranges.
# Iteration: 44 | current volfrac: 0.543875 | compliance: 0.001364
# Global iteration 44 is within one of the shape optimization ranges.
# Iteration: 45 | current volfrac: 0.532048 | compliance: 0.001389
# Global iteration 45 is within one of the shape optimization ranges.
# Iteration: 46 | current volfrac: 0.516602 | compliance: 0.001448
# Global iteration 46 is within one of the shape optimization ranges.
# Iteration: 47 | current volfrac: 0.498464 | compliance: 0.001514
# Global iteration 47 is within one of the shape optimization ranges.
# Iteration: 48 | current volfrac: 0.486898 | compliance: 0.001542
# Global iteration 48 is within one of the shape optimization ranges.
# Iteration: 49 | current volfrac: 0.484848 | compliance: 0.001524
# Global iteration 49 is within one of the shape optimization ranges.
# Iteration: 50 | current volfrac: 0.481490 | compliance: 0.001512
# Global iteration 50 is within one of the shape optimization ranges.
# Iteration: 51 | current volfrac: 0.477060 | compliance: 0.001511
# Global iteration 51 is within one of the shape optimization ranges.
# Iteration: 52 | current volfrac: 0.476074 | compliance: 0.001493
# Global iteration 52 is within one of the shape optimization ranges.
# Iteration: 53 | current volfrac: 0.464918 | compliance: 0.001540
# Global iteration 53 is within one of the shape optimization ranges.
# Iteration: 54 | current volfrac: 0.455347 | compliance: 0.001567
# Global iteration 54 is within one of the shape optimization ranges.
# Iteration: 55 | current volfrac: 0.447472 | compliance: 0.001601
# Global iteration 55 is within one of the shape optimization ranges.
# Iteration: 56 | current volfrac: 0.434058 | compliance: 0.001661
# Global iteration 56 is within one of the shape optimization ranges.
# Iteration: 57 | current volfrac: 0.429936 | compliance: 0.001661
# Global iteration 57 is within one of the shape optimization ranges.
# Iteration: 58 | current volfrac: 0.423697 | compliance: 0.001694
# Global iteration 58 is within one of the shape optimization ranges.
# Iteration: 59 | current volfrac: 0.418773 | compliance: 0.001715
# Global iteration 59 is within one of the shape optimization ranges.
# Iteration: 60 | current volfrac: 0.419147 | compliance: 0.001718
# Global iteration 60 is within one of the shape optimization ranges.
# Iteration: 61 | current volfrac: 0.412885 | compliance: 0.001738
# Global iteration 61 is within one of the shape optimization ranges.
# Iteration: 62 | current volfrac: 0.408869 | compliance: 0.001742
# Global iteration 62 is within one of the shape optimization ranges.
# Iteration: 63 | current volfrac: 0.410408 | compliance: 0.001737
# Global iteration 63 is within one of the shape optimization ranges.
# Iteration: 64 | current volfrac: 0.411349 | compliance: 0.001706
# Global iteration 64 is within one of the shape optimization ranges.
# Iteration: 65 | current volfrac: 0.410226 | compliance: 0.001714
# Global iteration 65 is within one of the shape optimization ranges.
# Iteration: 66 | current volfrac: 0.413779 | compliance: 0.001684
# Global iteration 66 is within one of the shape optimization ranges.
# Iteration: 67 | current volfrac: 0.413107 | compliance: 0.001686
# Global iteration 67 is within one of the shape optimization ranges.
# Iteration: 68 | current volfrac: 0.411492 | compliance: 0.001690
# Global iteration 68 is within one of the shape optimization ranges.
# Iteration: 69 | current volfrac: 0.415071 | compliance: 0.001662
# Global iteration 69 is within one of the shape optimization ranges.
# Iteration: 70 | current volfrac: 0.413803 | compliance: 0.001663
# Global iteration 70 is within one of the shape optimization ranges.
# Iteration: 71 | current volfrac: 0.405451 | compliance: 0.001711
# Global iteration 71 is within one of the shape optimization ranges.
# Computing stresses: 100%|██████████| 11098/11098 [00:00<00:00, 71667.59it/s]
# 0.511130675633319 0.0016860040135525803
# vf: 0.399113 | compliance: 0.001752 | max_stress: 0.708529

# %%
# geometry_features = TopOptimizer.method.gaussian_core.get_geometry()
# filename = None
# TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=True)

gray = False

# plot geometry
geometry_features = TopOptimizer.method.gaussian_core.get_geometry()

os.makedirs(root_dir, exist_ok=True)

if gray:
    filename = f"{root_dir}/{config_name}_gray.png"
    TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=not gray)
else:
    filename = f"{root_dir}/{config_name}_wr.png"
    TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=True)

vf, compliance, max_stress = TopOptimizer.print_metrics()
metrics = {
    "vf": vf,
    "compliance": compliance,
    "max_stress": max_stress
}
filename_metrics = f"{root_dir}/{config_name}_wr.json"
with open(filename_metrics, "w") as f:
    json.dump(metrics, f)
# Out:
# 0.511130675633319 0.0016860040135525803
# vf: 0.399113 | compliance: 0.001752 | max_stress: 0.708529
