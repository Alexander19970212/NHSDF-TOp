# %%
import sys
import os

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../models'))
sys.path.append(os.path.abspath('../dataset_generation'))
# sys.path.append('..')
# sys.path.append('../models')
from NN_TopOpt import FeatureMappingDecSDF, FeatureMappingTopOpt, SIMP_basic
from TopOpt import TopOptimizer2D
import yaml

methods = {
    "fm_nn_heaviside": FeatureMappingTopOpt,
}

# %%
import torch 
torch.cuda.empty_cache()

# select the experiment directory
# experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/AE_DeepSDF"
experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF"
# experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/MMD_VAE_DeepSDF"

config_name = "MBB_beam_half_fm_ae_hv" #
# config_name = "Cant_beam_half_fm_ae_hv"
# config_name = "Cant_beam_distrL_fm_ae_hv"
# config_name = "Brecket_fm_ae_hv"

config_path = f"{experiment_dir}/{config_name}.yaml"

with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

params = config['params']
params['refactoring_markers'] = list(range(38, 80, 5))
print(params['refactoring_markers'])
TopOptimizer = TopOptimizer2D(methods, params)
TopOptimizer.optimize(plot_interval=20)
# Out:
# [38, 43, 48, 53, 58, 63, 68, 73, 78]
# Info    : Reading '../test_problems/MBB_beam_half.msh'...
# Info    : 9 entities
# Info    : 5710 nodes
# Info    : 11098 elements
# Info    : Done reading '../test_problems/MBB_beam_half.msh'
# Compute areas ...
#   0%|          | 0/11098 [00:00<?, ?it/s]
# 100%|██████████| 11098/11098 [00:00<00:00, 146757.93it/s]
# 100%|██████████| 11098/11098 [00:00<00:00, 211978.62it/s]
# Whole area 0.48
# 100%|██████████| 11098/11098 [00:00<00:00, 33610.59it/s]
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/NN_TopOpt/NN_TopOpt.py:1119: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(saved_model_path)
# Fixed case:  fixed_x [0, [0, 0.4]] 41 5710
# Fixed case:  fixed_y [1.2, 0] 1 121
# Loaded loads:  (1,)
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/NN_TopOpt/NN_TopOpt.py:1643: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   self.H.T @ self.volumes/volume_goal - 1
# Iteration: 1 | current volfrac: 0.897464 | compliance: 599195.062500
# Iteration: 2 | current volfrac: 0.894584 | compliance: 601704.500000
# Iteration: 3 | current volfrac: 0.890602 | compliance: 604640.625000
# Iteration: 4 | current volfrac: 0.886589 | compliance: 604951.500000
# Iteration: 5 | current volfrac: 0.882722 | compliance: 605710.250000
# Iteration: 6 | current volfrac: 0.877874 | compliance: 606690.125000
# Iteration: 7 | current volfrac: 0.872955 | compliance: 608292.687500
# Iteration: 8 | current volfrac: 0.867677 | compliance: 609544.562500
# Iteration: 9 | current volfrac: 0.862019 | compliance: 610622.000000
# Iteration: 10 | current volfrac: 0.855779 | compliance: 612160.000000
# Iteration: 11 | current volfrac: 0.848971 | compliance: 614470.562500
# Iteration: 12 | current volfrac: 0.841699 | compliance: 617733.875000
# Iteration: 13 | current volfrac: 0.833665 | compliance: 621940.500000
# Iteration: 14 | current volfrac: 0.825268 | compliance: 626257.625000
# Iteration: 15 | current volfrac: 0.815947 | compliance: 631269.375000
# Iteration: 16 | current volfrac: 0.805986 | compliance: 636630.500000
# Iteration: 17 | current volfrac: 0.795218 | compliance: 642391.312500
# Iteration: 18 | current volfrac: 0.783099 | compliance: 650155.750000
# Iteration: 19 | current volfrac: 0.769434 | compliance: 659341.375000
# Iteration: 20 | current volfrac: 0.754263 | compliance: 671396.875000
# Iteration: 21 | current volfrac: 0.737932 | compliance: 689284.125000
# Iteration: 22 | current volfrac: 0.720434 | compliance: 708588.500000
# Iteration: 23 | current volfrac: 0.701874 | compliance: 727610.562500
# Iteration: 24 | current volfrac: 0.681008 | compliance: 759068.500000
# Iteration: 25 | current volfrac: 0.657177 | compliance: 808621.437500
# Iteration: 26 | current volfrac: 0.631646 | compliance: 867371.125000
# Iteration: 27 | current volfrac: 0.608127 | compliance: 911537.812500
# Iteration: 28 | current volfrac: 0.585052 | compliance: 962829.750000
# Iteration: 29 | current volfrac: 0.559331 | compliance: 1036983.312500
# Iteration: 30 | current volfrac: 0.550156 | compliance: 1063178.750000
# Iteration: 31 | current volfrac: 0.551729 | compliance: 1069184.500000
# Iteration: 32 | current volfrac: 0.560785 | compliance: 1056734.375000
# Iteration: 33 | current volfrac: 0.564334 | compliance: 1037200.125000
# Iteration: 34 | current volfrac: 0.563625 | compliance: 1036126.750000
# Iteration: 35 | current volfrac: 0.560407 | compliance: 1032531.625000
# Iteration: 36 | current volfrac: 0.555275 | compliance: 1035088.000000
# Iteration: 37 | current volfrac: 0.547861 | compliance: 1049337.250000
# Iteration: 38 | current volfrac: 0.537619 | compliance: 1095591.000000
# Refactoring started ...
# Iteration: 39 | current volfrac: 0.530098 | compliance: 1156195.250000
# Iteration: 40 | current volfrac: 0.523675 | compliance: 1177011.625000
# Global iteration 40 is within one of the shape optimization ranges.
# Iteration: 41 | current volfrac: 0.526404 | compliance: 1127852.375000
# Global iteration 41 is within one of the shape optimization ranges.
# Iteration: 42 | current volfrac: 0.528378 | compliance: 1096653.125000
# Global iteration 42 is within one of the shape optimization ranges.
# Iteration: 43 | current volfrac: 0.526924 | compliance: 1077048.000000
# Global iteration 43 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 44 | current volfrac: 0.524929 | compliance: 1098266.875000
# Global iteration 44 is within one of the shape optimization ranges.
# Iteration: 45 | current volfrac: 0.511179 | compliance: 1121430.125000
# Global iteration 45 is within one of the shape optimization ranges.
# Iteration: 46 | current volfrac: 0.495865 | compliance: 1168791.000000
# Global iteration 46 is within one of the shape optimization ranges.
# Iteration: 47 | current volfrac: 0.488900 | compliance: 1206958.000000
# Global iteration 47 is within one of the shape optimization ranges.
# Iteration: 48 | current volfrac: 0.489477 | compliance: 1140821.250000
# Global iteration 48 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 49 | current volfrac: 0.482624 | compliance: 1192963.250000
# Global iteration 49 is within one of the shape optimization ranges.
# Iteration: 50 | current volfrac: 0.483215 | compliance: 1162531.750000
# Global iteration 50 is within one of the shape optimization ranges.
# Iteration: 51 | current volfrac: 0.481025 | compliance: 1152594.500000
# Global iteration 51 is within one of the shape optimization ranges.
# Iteration: 52 | current volfrac: 0.473755 | compliance: 1167009.250000
# Global iteration 52 is within one of the shape optimization ranges.
# Iteration: 53 | current volfrac: 0.463538 | compliance: 1180460.375000
# Global iteration 53 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 54 | current volfrac: 0.451580 | compliance: 1259306.500000
# Global iteration 54 is within one of the shape optimization ranges.
# Iteration: 55 | current volfrac: 0.472744 | compliance: 1137089.250000
# Global iteration 55 is within one of the shape optimization ranges.
# Iteration: 56 | current volfrac: 0.486355 | compliance: 1078232.000000
# Global iteration 56 is within one of the shape optimization ranges.
# Iteration: 57 | current volfrac: 0.490360 | compliance: 1052967.000000
# Global iteration 57 is within one of the shape optimization ranges.
# Iteration: 58 | current volfrac: 0.484690 | compliance: 1060733.500000
# Global iteration 58 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 59 | current volfrac: 0.473591 | compliance: 1117965.750000
# Global iteration 59 is within one of the shape optimization ranges.
# Iteration: 60 | current volfrac: 0.453403 | compliance: 1230375.500000
# Global iteration 60 is within one of the shape optimization ranges.
# Iteration: 61 | current volfrac: 0.443611 | compliance: 1239739.500000
# Global iteration 61 is within one of the shape optimization ranges.
# Iteration: 62 | current volfrac: 0.437145 | compliance: 1242537.000000
# Global iteration 62 is within one of the shape optimization ranges.
# Iteration: 63 | current volfrac: 0.428331 | compliance: 1284380.750000
# Global iteration 63 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 64 | current volfrac: 0.450204 | compliance: 1249961.000000
# Global iteration 64 is within one of the shape optimization ranges.
# Iteration: 65 | current volfrac: 0.457542 | compliance: 1190200.500000
# Global iteration 65 is within one of the shape optimization ranges.
# Iteration: 66 | current volfrac: 0.459481 | compliance: 1154205.000000
# Global iteration 66 is within one of the shape optimization ranges.
# Iteration: 67 | current volfrac: 0.454594 | compliance: 1155312.875000
# Global iteration 67 is within one of the shape optimization ranges.
# Iteration: 68 | current volfrac: 0.443676 | compliance: 1192446.250000
# Global iteration 68 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 69 | current volfrac: 0.438260 | compliance: 1231801.000000
# Global iteration 69 is within one of the shape optimization ranges.
# Iteration: 70 | current volfrac: 0.422260 | compliance: 1323655.000000
# Global iteration 70 is within one of the shape optimization ranges.
# Iteration: 71 | current volfrac: 0.435480 | compliance: 1226229.500000
# Global iteration 71 is within one of the shape optimization ranges.
# Iteration: 72 | current volfrac: 0.447094 | compliance: 1160263.375000
# Global iteration 72 is within one of the shape optimization ranges.
# Iteration: 73 | current volfrac: 0.453214 | compliance: 1127560.750000
# Global iteration 73 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 74 | current volfrac: 0.451604 | compliance: 1168039.000000
# Global iteration 74 is within one of the shape optimization ranges.
# Iteration: 75 | current volfrac: 0.446132 | compliance: 1185933.625000
# Global iteration 75 is within one of the shape optimization ranges.
# Iteration: 76 | current volfrac: 0.437785 | compliance: 1208201.500000
# Global iteration 76 is within one of the shape optimization ranges.
# Iteration: 77 | current volfrac: 0.426401 | compliance: 1256988.500000
# Global iteration 77 is within one of the shape optimization ranges.
# Iteration: 78 | current volfrac: 0.432964 | compliance: 1214633.000000
# Global iteration 78 is within one of the shape optimization ranges.
# Refactoring started ...
# Iteration: 79 | current volfrac: 0.438634 | compliance: 1222378.500000
# Global iteration 79 is within one of the shape optimization ranges.

# %%
geometry_features = TopOptimizer.method.gaussian_core.get_geometry()

filename = None
TopOptimizer.plot_final_result(geometry_features, filename=filename)
