# %%
import sys
import os
import json

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../models'))
sys.path.append(os.path.abspath('../dataset_generation'))
# sys.path.append('..')
# sys.path.append('../models')
from NN_TopOpt import FeatureMappingDecSDF, FeatureMappingTopOpt, SIMP_basic
from TopOpt import TopOptimizer2D
import yaml

methods = {
    "fm_nn_heaviside": FeatureMappingTopOpt,
}

# %%
import torch 
torch.cuda.empty_cache()

# select the experiment directory
# experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/AE_DeepSDF"
experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF"
# experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/MMD_VAE_DeepSDF"

# config_name = "MBB_beam_half_fm_ae_hv" #
# config_name = "Cant_beam_half_fm_ae_hv"
# config_name = "Cant_beam_distrL_fm_ae_hv"
# config_name = "Brecket_fm_ae_hv"


config_name = "MBB_beam_half" #
# config_name = "Cant_beam"
# config_name = "Cant_beam_distrL"
# config_name = "Brecket"

# config_name = "Square_beam"
# config_name = "Square_beam_distrL"
# config_name = "Square_cantilever_beam"

config_path = f"{experiment_dir}/{config_name}.yaml"

with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

params = config['params']
# params['refactoring_markers'] = list(range(38, 80, 5))
params['refactoring_markers'] = []
# params['treshold'] = 0.5
TopOptimizer = TopOptimizer2D(methods, params)
TopOptimizer.optimize(plot_interval=5)
vf, compliance, max_stress = TopOptimizer.print_metrics()
# Out:
# Info    : Reading '../test_problems/MBB_beam_half.msh'...
# Info    : 9 entities
# Info    : 5710 nodes
# Info    : 11098 elements
# Info    : Done reading '../test_problems/MBB_beam_half.msh'
# Compute areas ...
# 100%|██████████| 11098/11098 [00:00<00:00, 129983.12it/s]
# 100%|██████████| 11098/11098 [00:00<00:00, 168317.55it/s]
# Whole area 0.48
# 100%|██████████| 11098/11098 [00:00<00:00, 33178.89it/s]
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/NN_TopOpt/NN_TopOpt.py:1124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(saved_model_path)
# Fixed case:  fixed_x [0, [0, 0.4]] 41 5710
# Fixed case:  fixed_y [1.2, 0] 1 121
# Loaded loads:  (1,)
# 40
# /home/kalexu97/Projects/carpenter-sdf-topology-optimizer/NN_TopOpt/NN_TopOpt.py:1666: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   self.H.T @ self.volumes/volume_goal - 1
# Iteration: 1 | current volfrac: 0.914791 | compliance: 0.000808
# Iteration: 2 | current volfrac: 0.911860 | compliance: 0.000811
# Iteration: 3 | current volfrac: 0.907825 | compliance: 0.000816
# Iteration: 4 | current volfrac: 0.904027 | compliance: 0.000815
# Iteration: 5 | current volfrac: 0.899913 | compliance: 0.000818
# Iteration: 6 | current volfrac: 0.895245 | compliance: 0.000822
# Iteration: 7 | current volfrac: 0.890487 | compliance: 0.000826
# Iteration: 8 | current volfrac: 0.885157 | compliance: 0.000829
# Iteration: 9 | current volfrac: 0.879452 | compliance: 0.000831
# Iteration: 10 | current volfrac: 0.873219 | compliance: 0.000833
# Iteration: 11 | current volfrac: 0.866578 | compliance: 0.000836
# Iteration: 12 | current volfrac: 0.859056 | compliance: 0.000840
# Iteration: 13 | current volfrac: 0.851244 | compliance: 0.000847
# Iteration: 14 | current volfrac: 0.842506 | compliance: 0.000848
# Iteration: 15 | current volfrac: 0.833340 | compliance: 0.000852
# Iteration: 16 | current volfrac: 0.823719 | compliance: 0.000857
# Iteration: 17 | current volfrac: 0.813197 | compliance: 0.000866
# Iteration: 18 | current volfrac: 0.801402 | compliance: 0.000876
# Iteration: 19 | current volfrac: 0.787931 | compliance: 0.000889
# Iteration: 20 | current volfrac: 0.773339 | compliance: 0.000910
# Iteration: 21 | current volfrac: 0.757233 | compliance: 0.000935
# Iteration: 22 | current volfrac: 0.740219 | compliance: 0.000954
# Iteration: 23 | current volfrac: 0.722814 | compliance: 0.000973
# Iteration: 24 | current volfrac: 0.703600 | compliance: 0.001002
# Iteration: 25 | current volfrac: 0.681168 | compliance: 0.001048
# Iteration: 26 | current volfrac: 0.655152 | compliance: 0.001123
# Iteration: 27 | current volfrac: 0.626530 | compliance: 0.001222
# Iteration: 28 | current volfrac: 0.601663 | compliance: 0.001310
# Iteration: 29 | current volfrac: 0.582391 | compliance: 0.001374
# Iteration: 30 | current volfrac: 0.565411 | compliance: 0.001453
# Iteration: 31 | current volfrac: 0.551946 | compliance: 0.001542
# Iteration: 32 | current volfrac: 0.545967 | compliance: 0.001575
# Iteration: 33 | current volfrac: 0.546577 | compliance: 0.001566
# Iteration: 34 | current volfrac: 0.551601 | compliance: 0.001511
# Iteration: 35 | current volfrac: 0.558906 | compliance: 0.001451
# Iteration: 36 | current volfrac: 0.566874 | compliance: 0.001409
# Iteration: 37 | current volfrac: 0.574511 | compliance: 0.001367
# Iteration: 38 | current volfrac: 0.581103 | compliance: 0.001337
# Iteration: 39 | current volfrac: 0.585923 | compliance: 0.001306
# Iteration: 40 | current volfrac: 0.587339 | compliance: 0.001300
# Global iteration 40 is within one of the shape optimization ranges.
# Iteration: 41 | current volfrac: 0.580576 | compliance: 0.001307
# Global iteration 41 is within one of the shape optimization ranges.
# Iteration: 42 | current volfrac: 0.570558 | compliance: 0.001321
# Global iteration 42 is within one of the shape optimization ranges.
# Iteration: 43 | current volfrac: 0.558012 | compliance: 0.001344
# Global iteration 43 is within one of the shape optimization ranges.
# Iteration: 44 | current volfrac: 0.545229 | compliance: 0.001368
# Global iteration 44 is within one of the shape optimization ranges.
# Iteration: 45 | current volfrac: 0.533887 | compliance: 0.001385
# Global iteration 45 is within one of the shape optimization ranges.
# Iteration: 46 | current volfrac: 0.521380 | compliance: 0.001416
# Global iteration 46 is within one of the shape optimization ranges.
# Iteration: 47 | current volfrac: 0.507794 | compliance: 0.001469
# Global iteration 47 is within one of the shape optimization ranges.
# Iteration: 48 | current volfrac: 0.497251 | compliance: 0.001512
# Global iteration 48 is within one of the shape optimization ranges.
# Iteration: 49 | current volfrac: 0.490235 | compliance: 0.001541
# Global iteration 49 is within one of the shape optimization ranges.
# Iteration: 50 | current volfrac: 0.485800 | compliance: 0.001555
# Global iteration 50 is within one of the shape optimization ranges.
# Iteration: 51 | current volfrac: 0.485958 | compliance: 0.001534
# Global iteration 51 is within one of the shape optimization ranges.
# Iteration: 52 | current volfrac: 0.486326 | compliance: 0.001514
# Global iteration 52 is within one of the shape optimization ranges.
# Iteration: 53 | current volfrac: 0.484577 | compliance: 0.001520
# Global iteration 53 is within one of the shape optimization ranges.
# Iteration: 54 | current volfrac: 0.485219 | compliance: 0.001498
# Global iteration 54 is within one of the shape optimization ranges.
# Iteration: 55 | current volfrac: 0.481735 | compliance: 0.001508
# Global iteration 55 is within one of the shape optimization ranges.
# Iteration: 56 | current volfrac: 0.475066 | compliance: 0.001534
# Global iteration 56 is within one of the shape optimization ranges.
# Iteration: 57 | current volfrac: 0.467763 | compliance: 0.001562
# Global iteration 57 is within one of the shape optimization ranges.
# Iteration: 58 | current volfrac: 0.458170 | compliance: 0.001615
# Global iteration 58 is within one of the shape optimization ranges.
# Iteration: 59 | current volfrac: 0.451798 | compliance: 0.001641
# Global iteration 59 is within one of the shape optimization ranges.
# Iteration: 60 | current volfrac: 0.450848 | compliance: 0.001640
# Global iteration 60 is within one of the shape optimization ranges.
# Iteration: 61 | current volfrac: 0.450548 | compliance: 0.001634
# Global iteration 61 is within one of the shape optimization ranges.
# Iteration: 62 | current volfrac: 0.450071 | compliance: 0.001633
# Global iteration 62 is within one of the shape optimization ranges.
# Iteration: 63 | current volfrac: 0.447444 | compliance: 0.001639
# Global iteration 63 is within one of the shape optimization ranges.
# Iteration: 64 | current volfrac: 0.442935 | compliance: 0.001656
# Global iteration 64 is within one of the shape optimization ranges.
# Iteration: 65 | current volfrac: 0.441281 | compliance: 0.001659
# Global iteration 65 is within one of the shape optimization ranges.
# Iteration: 66 | current volfrac: 0.441878 | compliance: 0.001645
# Global iteration 66 is within one of the shape optimization ranges.
# Iteration: 67 | current volfrac: 0.443964 | compliance: 0.001624
# Global iteration 67 is within one of the shape optimization ranges.
# Iteration: 68 | current volfrac: 0.444218 | compliance: 0.001613
# Global iteration 68 is within one of the shape optimization ranges.
# Iteration: 69 | current volfrac: 0.442866 | compliance: 0.001614
# Global iteration 69 is within one of the shape optimization ranges.
# Iteration: 70 | current volfrac: 0.442003 | compliance: 0.001611
# Global iteration 70 is within one of the shape optimization ranges.
# Iteration: 71 | current volfrac: 0.437308 | compliance: 0.001631
# Global iteration 71 is within one of the shape optimization ranges.
# Computing stresses: 100%|██████████| 11098/11098 [00:00<00:00, 80706.68it/s]
# 0.5273052548513814 0.0015229673040869965
# vf: 0.431378 | compliance: 0.001662 | max_stress: 0.527305

# %%
# geometry_features = TopOptimizer.method.gaussian_core.get_geometry()
# filename = None
# TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=True)

gray = False

# plot geometry
geometry_features = TopOptimizer.method.gaussian_core.get_geometry()

root_dir = "../src/model_comparison/NHSDF"

os.makedirs(root_dir, exist_ok=True)

if gray:
    filename = f"{root_dir}/{config_name}_gray.png"
    TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=not gray)
else:
    filename = f"{root_dir}/{config_name}_wr.png"
    TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=True)

vf, compliance, max_stress = TopOptimizer.print_metrics()
metrics = {
    "vf": vf,
    "compliance": compliance,
    "max_stress": max_stress
}
filename_metrics = f"{root_dir}/{config_name}_wr.json"
with open(filename_metrics, "w") as f:
    json.dump(metrics, f)
# Out:
# 0.5273052548513814 0.0015229673040869965
# vf: 0.431378 | compliance: 0.001662 | max_stress: 0.527305
