# %%
import sys
import os
import json

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../models'))
sys.path.append(os.path.abspath('../dataset_generation'))
# sys.path.append('..')
# sys.path.append('../models')
from NN_TopOpt import FeatureMappingDecSDF, FeatureMappingTopOpt, SIMP_basic
from TopOpt import TopOptimizer2D
import yaml

methods = {
    "fm_nn_heaviside": FeatureMappingTopOpt,
}

# %%
import torch 
torch.cuda.empty_cache()

# dataset_type = "quadrangle"
dataset_type = "triangle"
root_dir = "../src/model_comparison/NHSDF"

# select the experiment directory
if dataset_type == "tripple":
    # experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/AE_DeepSDF"
    experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF"
    # experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/MMD_VAE_DeepSDF"
elif dataset_type == "quadrangle":
    experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF_quad"
    root_dir += "_quad"
elif dataset_type == "triangle":
    experiment_dir = "../configs/NN_top_optimization/FM_NN_Heaviside/VAE_DeepSDF_triangl"
    root_dir += "_triangl"


# config_name = "MBB_beam_half_fm_ae_hv" #
# config_name = "Cant_beam_half_fm_ae_hv"
# config_name = "Cant_beam_distrL_fm_ae_hv"
# config_name = "Brecket_fm_ae_hv"


config_name = "MBB_beam_half" #
# config_name = "Cant_beam"
# config_name = "Cant_beam_distrL"
# config_name = "Brecket"

# config_name = "Square_beam"
# config_name = "Square_beam_distrL"
# config_name = "Square_cantilever_beam"

config_path = f"{experiment_dir}/{config_name}.yaml"

with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

params = config['params']
# params['refactoring_markers'] = list(range(38, 80, 5))
params['refactoring_markers'] = []
# params['treshold'] = 0.5
TopOptimizer = TopOptimizer2D(methods, params)
TopOptimizer.optimize(plot_interval=5)
vf, compliance, max_stress = TopOptimizer.print_metrics()
# Out:
# Info    : Reading '../test_problems/Square_cantilever_beam.msh'...
# Info    : 9 entities
# Info    : 5381 nodes
# Info    : 10492 elements
# Info    : Done reading '../test_problems/Square_cantilever_beam.msh'
# Compute areas ...
# 100%|██████████| 10492/10492 [00:00<00:00, 160955.93it/s]
# 100%|██████████| 10492/10492 [00:00<00:00, 218023.02it/s]
# Whole area 1.0
# 100%|██████████| 10492/10492 [00:00<00:00, 35456.94it/s]
# Fixed case:  fixed_xy [0, [0, 1]] 68 5381
# Loaded loads:  (4,)
# 60
# ../model_weights/frst_VAE_DeepSDF_quad_Bprec_full.pt
# Iteration: 1 | current volfrac: 0.894068 | compliance: 9.640309
# Iteration: 2 | current volfrac: 0.886715 | compliance: 9.383972
# Iteration: 3 | current volfrac: 0.878866 | compliance: 9.103749
# Iteration: 4 | current volfrac: 0.870458 | compliance: 8.784855
# Iteration: 5 | current volfrac: 0.870325 | compliance: 8.505501
# Iteration: 6 | current volfrac: 0.872957 | compliance: 8.419756
# Iteration: 7 | current volfrac: 0.868193 | compliance: 8.449429
# Iteration: 8 | current volfrac: 0.857729 | compliance: 8.557414
# Iteration: 9 | current volfrac: 0.843232 | compliance: 8.743258
# Iteration: 10 | current volfrac: 0.825676 | compliance: 9.031821
# Iteration: 11 | current volfrac: 0.806067 | compliance: 9.439280
# Iteration: 12 | current volfrac: 0.786023 | compliance: 9.959389
# Iteration: 13 | current volfrac: 0.766903 | compliance: 10.522376
# Iteration: 14 | current volfrac: 0.749885 | compliance: 10.969810
# Iteration: 15 | current volfrac: 0.735709 | compliance: 11.217405
# Iteration: 16 | current volfrac: 0.725024 | compliance: 11.259153
# Iteration: 17 | current volfrac: 0.716584 | compliance: 11.210052
# Iteration: 18 | current volfrac: 0.708573 | compliance: 11.176111
# Iteration: 19 | current volfrac: 0.699011 | compliance: 11.251640
# Iteration: 20 | current volfrac: 0.686839 | compliance: 11.450541
# Iteration: 21 | current volfrac: 0.671476 | compliance: 11.757923
# Iteration: 22 | current volfrac: 0.652540 | compliance: 12.199917
# Iteration: 23 | current volfrac: 0.630030 | compliance: 12.838115
# Iteration: 24 | current volfrac: 0.604905 | compliance: 13.652032
# Iteration: 25 | current volfrac: 0.578509 | compliance: 14.583765
# Iteration: 26 | current volfrac: 0.553274 | compliance: 15.627392
# Iteration: 27 | current volfrac: 0.559984 | compliance: 15.229808
# Iteration: 28 | current volfrac: 0.583206 | compliance: 14.270717
# Iteration: 29 | current volfrac: 0.600840 | compliance: 13.647629
# Iteration: 30 | current volfrac: 0.611955 | compliance: 13.240405
# Iteration: 31 | current volfrac: 0.616614 | compliance: 13.019129
# Iteration: 32 | current volfrac: 0.615171 | compliance: 12.990944
# Iteration: 33 | current volfrac: 0.608191 | compliance: 13.148667
# Iteration: 34 | current volfrac: 0.596306 | compliance: 13.499825
# Iteration: 35 | current volfrac: 0.580414 | compliance: 14.083706
# Iteration: 36 | current volfrac: 0.562243 | compliance: 14.890107
# Iteration: 37 | current volfrac: 0.544795 | compliance: 15.761062
# Iteration: 38 | current volfrac: 0.531719 | compliance: 16.435915
# Iteration: 39 | current volfrac: 0.525626 | compliance: 16.648830
# Iteration: 40 | current volfrac: 0.525734 | compliance: 16.453953
# Global iteration 40 is within one of the shape optimization ranges.
# Iteration: 41 | current volfrac: 0.521380 | compliance: 16.248417
# Global iteration 41 is within one of the shape optimization ranges.
# Iteration: 42 | current volfrac: 0.512016 | compliance: 16.263254
# Global iteration 42 is within one of the shape optimization ranges.
# Iteration: 43 | current volfrac: 0.505795 | compliance: 16.060955
# Global iteration 43 is within one of the shape optimization ranges.
# Iteration: 44 | current volfrac: 0.496686 | compliance: 15.979861
# Global iteration 44 is within one of the shape optimization ranges.
# Iteration: 45 | current volfrac: 0.482559 | compliance: 16.137093
# Global iteration 45 is within one of the shape optimization ranges.
# Iteration: 46 | current volfrac: 0.462998 | compliance: 16.655424
# Global iteration 46 is within one of the shape optimization ranges.
# Iteration: 47 | current volfrac: 0.481026 | compliance: 15.616377
# Global iteration 47 is within one of the shape optimization ranges.
# Iteration: 48 | current volfrac: 0.490252 | compliance: 15.117030
# Global iteration 48 is within one of the shape optimization ranges.
# Iteration: 49 | current volfrac: 0.487983 | compliance: 15.053745
# Global iteration 49 is within one of the shape optimization ranges.
# Iteration: 50 | current volfrac: 0.474731 | compliance: 15.451896
# Global iteration 50 is within one of the shape optimization ranges.
# Iteration: 51 | current volfrac: 0.452950 | compliance: 16.334724
# Global iteration 51 is within one of the shape optimization ranges.
# Iteration: 52 | current volfrac: 0.428290 | compliance: 17.528721
# Global iteration 52 is within one of the shape optimization ranges.
# Iteration: 53 | current volfrac: 0.445614 | compliance: 16.556677
# Global iteration 53 is within one of the shape optimization ranges.
# Iteration: 54 | current volfrac: 0.453527 | compliance: 16.129646
# Global iteration 54 is within one of the shape optimization ranges.
# Iteration: 55 | current volfrac: 0.451228 | compliance: 16.145905
# Global iteration 55 is within one of the shape optimization ranges.
# Iteration: 56 | current volfrac: 0.440167 | compliance: 16.572357
# Global iteration 56 is within one of the shape optimization ranges.
# Iteration: 57 | current volfrac: 0.423012 | compliance: 17.324965
# Global iteration 57 is within one of the shape optimization ranges.
# Iteration: 58 | current volfrac: 0.402273 | compliance: 18.376411
# Global iteration 58 is within one of the shape optimization ranges.
# Iteration: 59 | current volfrac: 0.419762 | compliance: 17.404921
# Global iteration 59 is within one of the shape optimization ranges.
# Iteration: 60 | current volfrac: 0.426564 | compliance: 17.078548
# Global iteration 60 is within one of the shape optimization ranges.
# Iteration: 61 | current volfrac: 0.422205 | compliance: 17.258430
# Global iteration 61 is within one of the shape optimization ranges.
# Iteration: 62 | current volfrac: 0.409348 | compliance: 17.826813
# Global iteration 62 is within one of the shape optimization ranges.
# Iteration: 63 | current volfrac: 0.393287 | compliance: 18.720612
# Global iteration 63 is within one of the shape optimization ranges.
# Iteration: 64 | current volfrac: 0.415385 | compliance: 17.463280
# Global iteration 64 is within one of the shape optimization ranges.
# Iteration: 65 | current volfrac: 0.428176 | compliance: 16.874149
# Global iteration 65 is within one of the shape optimization ranges.
# Iteration: 66 | current volfrac: 0.430245 | compliance: 16.748804
# Global iteration 66 is within one of the shape optimization ranges.
# Iteration: 67 | current volfrac: 0.422210 | compliance: 17.086411
# Global iteration 67 is within one of the shape optimization ranges.
# Iteration: 68 | current volfrac: 0.406009 | compliance: 17.846931
# Global iteration 68 is within one of the shape optimization ranges.
# Iteration: 69 | current volfrac: 0.385564 | compliance: 19.015005
# Global iteration 69 is within one of the shape optimization ranges.
# Iteration: 70 | current volfrac: 0.402672 | compliance: 17.974674
# Global iteration 70 is within one of the shape optimization ranges.
# Iteration: 71 | current volfrac: 0.413915 | compliance: 17.382036
# Global iteration 71 is within one of the shape optimization ranges.
# Iteration: 72 | current volfrac: 0.417041 | compliance: 17.231190
# Global iteration 72 is within one of the shape optimization ranges.
# Iteration: 73 | current volfrac: 0.411797 | compliance: 17.477888
# Global iteration 73 is within one of the shape optimization ranges.
# Iteration: 74 | current volfrac: 0.399590 | compliance: 18.083460
# Global iteration 74 is within one of the shape optimization ranges.
# Iteration: 75 | current volfrac: 0.415234 | compliance: 17.288101
# Global iteration 75 is within one of the shape optimization ranges.
# Iteration: 76 | current volfrac: 0.421565 | compliance: 16.970425
# Global iteration 76 is within one of the shape optimization ranges.
# Iteration: 77 | current volfrac: 0.418867 | compliance: 17.084715
# Global iteration 77 is within one of the shape optimization ranges.
# Iteration: 78 | current volfrac: 0.409058 | compliance: 17.574524
# Global iteration 78 is within one of the shape optimization ranges.
# Iteration: 79 | current volfrac: 0.395054 | compliance: 18.330072
# Global iteration 79 is within one of the shape optimization ranges.
# Iteration: 80 | current volfrac: 0.411020 | compliance: 17.428085
# Global iteration 80 is within one of the shape optimization ranges.
# Iteration: 81 | current volfrac: 0.419436 | compliance: 17.031334
# Global iteration 81 is within one of the shape optimization ranges.
# Iteration: 82 | current volfrac: 0.419543 | compliance: 17.032169
# Global iteration 82 is within one of the shape optimization ranges.
# Iteration: 83 | current volfrac: 0.412011 | compliance: 17.363663
# Global iteration 83 is within one of the shape optimization ranges.
# Iteration: 84 | current volfrac: 0.398392 | compliance: 18.030426
# Global iteration 84 is within one of the shape optimization ranges.
# Iteration: 85 | current volfrac: 0.410757 | compliance: 17.400875
# Global iteration 85 is within one of the shape optimization ranges.
# Iteration: 86 | current volfrac: 0.415808 | compliance: 17.159481
# Global iteration 86 is within one of the shape optimization ranges.
# Iteration: 87 | current volfrac: 0.413747 | compliance: 17.252144
# Global iteration 87 is within one of the shape optimization ranges.
# Iteration: 88 | current volfrac: 0.405653 | compliance: 17.643984
# Global iteration 88 is within one of the shape optimization ranges.
# Iteration: 89 | current volfrac: 0.393299 | compliance: 18.288277
# Global iteration 89 is within one of the shape optimization ranges.
# Iteration: 90 | current volfrac: 0.407070 | compliance: 17.552191
# Global iteration 90 is within one of the shape optimization ranges.
# Iteration: 91 | current volfrac: 0.413781 | compliance: 17.232409
# Global iteration 91 is within one of the shape optimization ranges.
# Iteration: 92 | current volfrac: 0.413322 | compliance: 17.250343
# Global iteration 92 is within one of the shape optimization ranges.
# Iteration: 93 | current volfrac: 0.406523 | compliance: 17.563839
# Global iteration 93 is within one of the shape optimization ranges.
# Iteration: 94 | current volfrac: 0.394989 | compliance: 18.158321
# Global iteration 94 is within one of the shape optimization ranges.
# Iteration: 95 | current volfrac: 0.408146 | compliance: 17.466665
# Global iteration 95 is within one of the shape optimization ranges.
# Iteration: 96 | current volfrac: 0.414799 | compliance: 17.140900
# Global iteration 96 is within one of the shape optimization ranges.
# Iteration: 97 | current volfrac: 0.414789 | compliance: 17.136654
# Global iteration 97 is within one of the shape optimization ranges.
# Iteration: 98 | current volfrac: 0.408831 | compliance: 17.421984
# Global iteration 98 is within one of the shape optimization ranges.
# Iteration: 99 | current volfrac: 0.398242 | compliance: 17.961983
# Global iteration 99 is within one of the shape optimization ranges.
# Computing stresses: 100%|██████████| 10492/10492 [00:00<00:00, 107364.95it/s]
# 29.62569527513259 0.007038810039040188
# vf: 0.406834 | compliance: 15.380575 | max_stress: 29.625695

# %%
# geometry_features = TopOptimizer.method.gaussian_core.get_geometry()
# filename = None
# TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=True)

gray = False

# plot geometry
geometry_features = TopOptimizer.method.gaussian_core.get_geometry()

os.makedirs(root_dir, exist_ok=True)

if gray:
    filename = f"{root_dir}/{config_name}_gray.png"
    TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=not gray)
else:
    filename = f"{root_dir}/{config_name}.png"
    TopOptimizer.plot_final_result(geometry_features, filename=filename, plot_von_mises=True)

vf, compliance, max_stress = TopOptimizer.print_metrics()
metrics = {
    "vf": vf,
    "compliance": compliance,
    "max_stress": max_stress
}
filename_metrics = f"{root_dir}/{config_name}.json"
with open(filename_metrics, "w") as f:
    json.dump(metrics, f)
# Out:
# 29.62569527513259 0.007038810039040188
# vf: 0.406834 | compliance: 15.380575 | max_stress: 29.625695
