# %%
from RS_dataset import RSLossConvDataset
# Visualize the grid using matplotlib
import matplotlib.pyplot as plt

sample_dataset = RSLossConvDataset(root_dir='../shape_datasets/RS_loss_datasets', 
                       shape_type='triangle', grid_size=40)
sample_sample = sample_dataset[4]
print(sample_sample['grid'].shape)
print(sample_sample['target'])

plt.figure(figsize=(8, 8))
plt.imshow(sample_sample['grid'][0], cmap='viridis')
plt.colorbar(label='Z value')
plt.title('Grid Visualization')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# torch.Size([1, 40, 40])
# tensor([0.1521])
