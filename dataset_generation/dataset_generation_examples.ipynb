# %%
# examples with generation dataset for ellipsoides
from ellipse_sdf import generate_ellipse_sdf_dataset, plot_ellipse_sdf_dataset

# dataset_path = '../shape_datasets/ellipse_sdf_dataset_test.csv'
dataset_path = '../../mnt/local/data/kalexu97/topOpt/ellipse_sdf_dataset.csv'
df = generate_ellipse_sdf_dataset(num_ellipse=3000, points_per_ellipse=1000, filename=dataset_path)
plot_ellipse_sdf_dataset(df, points_per_ellipse=1000)
# Out:
# 00%|██████████████████████████████████████████████████████████████| 3000/3000 [00:04<00:00, 678.68it/s]
# Dataset saved to ../../mnt/local/data/kalexu97/topOpt/ellipse_sdf_dataset.csv
# 0.5 0.38533090013390264
# 0.5 0.7241459827482866
# 0.5 0.718731814510745

# %%
# examples with generation dataset for quadrangle
from quadrangle_sdf import generate_quadrangle_sdf_dataset, plot_quadrangle_sdf_dataset

dataset_path = '../shape_datasets/quadrangle_sdf_dataset_test.csv'
df = generate_quadrangle_sdf_dataset(num_quadrangle=100, points_per_quadrangle=500, filename=dataset_path)
plot_quadrangle_sdf_dataset(df)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 38.23it/s]
# Dataset saved to ../shape_datasets/quadrangle_sdf_dataset_test.csv

# %%
# examples with generation dataset for triangle
from triangle_sdf import generate_triangle_sdf_dataset, plot_triangle_sdf_dataset

dataset_path = '../shape_datasets/triangle_sdf_dataset_test.csv'
df = generate_triangle_sdf_dataset(num_triangle=100, points_per_triangle=500, filename=dataset_path)
plot_triangle_sdf_dataset(df)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 50.28it/s]
# Dataset saved to ../shape_datasets/triangle_sdf_dataset_test.csv

# %%
# examples with generation dataset for triangle with rounded corners
from triangle_sdf import generate_rounded_triangle_sdf_dataset, plot_triangle_sdf_dataset

# dataset_path = '../shape_datasets/triangle_sdf_dataset_test.csv'
dataset_path = '../../mnt/local/data/kalexu97/topOpt/rounded_triangle_sdf_dataset.csv'
df = generate_rounded_triangle_sdf_dataset(num_triangle=3000, points_per_triangle=1000, filename=dataset_path)
plot_triangle_sdf_dataset(df, points_per_triangle=1000)
# Out:
# 00%|███████████████████████████████████████████████████████████████| 3000/3000 [01:05<00:00, 46.00it/s]
# Dataset saved to ../../mnt/local/data/kalexu97/topOpt/rounded_triangle_sdf_dataset.csv

# %%
# examples with generation dataset for quadrangle with rounded corners
from quadrangle_sdf import generate_rounded_quadrangle_sdf_dataset, plot_quadrangle_sdf_dataset

# dataset_path = '../shape_datasets/quadrangle_sdf_dataset_test.csv'
dataset_path = '../../mnt/local/data/kalexu97/topOpt/rounded_quadrangle_sdf_dataset.csv'
df = generate_rounded_quadrangle_sdf_dataset(num_quadrangle=3000, points_per_quadrangle=1000, filename=dataset_path)
plot_quadrangle_sdf_dataset(df, points_per_quadrangle=1000)
# Out:
# 00%|███████████████████████████████████████████████████████████████| 3000/3000 [01:19<00:00, 37.51it/s]
# Dataset saved to ../../mnt/local/data/kalexu97/topOpt/rounded_quadrangle_sdf_dataset.csv

# %%
from ellipse_sdf import generate_ellipse_sdf_surface_dataset, plot_ellipse_sdf_dataset
from utils_generation import plot_sample_from_df

# dataset_path = '../shape_datasets/ellipse_sdf_surface_dataset_test'
dataset_path = '../../mnt/local/data/kalexu97/topOpt/ellipse_sdf_surface_dataset' # without .csv!!
df, points_df = generate_ellipse_sdf_surface_dataset(num_ellipse=100, points_per_ellipse=1225, filename=dataset_path)
plot_sample_from_df(df, points_df, sample_index=8)
# Out:
# 00%|████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 478.18it/s]
# Dataset saved to ../../mnt/local/data/kalexu97/topOpt/ellipse_sdf_surface_dataset
# Points grid saved to points_grid.csv

# %%
from quadrangle_sdf import generate_rounded_quadrangle_sdf_surface_dataset, plot_quadrangle_sdf_dataset

# dataset_path = '../shape_datasets/quadrangle_sdf_surface_dataset_test'
dataset_path = '../../mnt/local/data/kalexu97/topOpt/rounded_quadrangle_sdf_surface_dataset' # without .csv!!
df, points_df = generate_rounded_quadrangle_sdf_surface_dataset(num_quadrangle=100, points_per_quadrangle=1225, filename=dataset_path)
plot_sample_from_df(df, points_df, sample_index=8)
# Out:
# 00%|█████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 31.90it/s]
# Dataset saved to ../../mnt/local/data/kalexu97/topOpt/rounded_quadrangle_sdf_surface_dataset
# Points grid saved to points_grid.csv

# %%
from triangle_sdf import generate_rounded_triangle_sdf_surface_dataset, plot_triangle_sdf_dataset

# dataset_path = '../shape_datasets/triangle_sdf_surface_dataset_test'
dataset_path = '../../mnt/local/data/kalexu97/topOpt/rounded_triangle_sdf_surface_dataset' # without .csv !!
df, points_df = generate_rounded_triangle_sdf_surface_dataset(num_triangle=100, points_per_triangle=1225, filename=dataset_path)
plot_sample_from_df(df, points_df, sample_index=8)
# Out:
# 00%|█████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 39.92it/s]
# Dataset saved to ../../mnt/local/data/kalexu97/topOpt/rounded_triangle_sdf_surface_dataset
# Points grid saved to points_grid.csv
